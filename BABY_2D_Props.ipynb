# %%
import fenics as f
import matplotlib.pyplot as plt
from models import velocity_field, t_transport_sim, mesh_2d
import h_transport_materials as htm

# %%
if __name__ == "__main__":
    # Generating mesh
    # x1 = 0.00476
    # x2 = 0.0162
    # y1 = 0.01
    # y2 = 0.0761
    # resolution = 30
    # mesh_fenics, surface_markers, left_id, top_id, right_id, bottom_id, upper_left_id, left_top_id = LMeshmshr(x1, x2, y1, y2, resolution)

    mesh_fenics, volume_markers, surface_markers, correspondance_dict = mesh_2d()


    # filter only flibe and H
    diffusivities = htm.diffusivities.filter(material="flibe")
    for prop in diffusivities:
        print(prop)
        
    # plot the properties
    plt.figure()
    htm.plotting.plot(diffusivities)
    plt.yscale("log")
    plt.ylabel("Diffusivity (m$^2$/s)")
    plt.legend()
    plt.show()

    k_array_array = []
    for diffusivity in diffusivities:

        T_hot = 700 + 273.15
        dt_array = [0, 0.05, 0.1, 0.175, 0.25, 1, 2.5, 5, 10]
        k_array = []
        for dT in dt_array:
            print(f"----------  Running for dT={dT} K  ----------")
            foldername = f"Results/dt={dT}/"
            T_cold = T_hot - dT
            u, p, T = velocity_field(
                T_cold=T_cold,
                T_hot=T_hot,
                my_mesh=mesh_fenics,
                surface_markers=surface_markers,
                correspondance_dict=correspondance_dict,
            )

            f.XDMFFile(foldername + "temperature_field.xdmf").write_checkpoint(
                T, "temperature", 1, f.XDMFFile.Encoding.HDF5
            )
            f.XDMFFile(foldername + "velocity_field.xdmf").write(u)

            plt.figure()
            plt.title("Velocity field")
            CS = f.plot(u, scale=1e-3)
            plt.colorbar(CS, label="m/s")
            plt.show()

            # plt.figure()
            # TS = f.plot(T, cmap="inferno")
            # plt.colorbar(TS, label="K")
            # plt.show()

            k = t_transport_sim(
                T,
                mesh_fenics,
                u,
                volume_markers=volume_markers,
                surface_markers=surface_markers,
                correspondance_dict=correspondance_dict, 
                D_0 = diffusivity.pre_exp.magnitude, 
                E_D = diffusivity.act_energy.magnitude
            )
            # print(k)
            k_array.append(k[0])

        k_array_array.append(k_array)
# Out:
#         Author: Calderoni
#         Material: flibe
#         Year: 2008
#         Isotope: T
#         Pre-exponential factor: 9.30×10⁻⁷ m²/s
#         Activation energy: 4.35×10⁻¹ eV/particle
#         *** Warning: Matplotlib plotting backend does not support mesh function of dim 1. Continuing without plotting...
#
#
#         Author: Anderl
#         Material: flibe
#         Year: 2004
#         Isotope: D
#         Pre-exponential factor: 3.17×10¹ m²/s
#         Activation energy: 1.84×10⁰ eV/particle
#
#
#         Author: Oishi
#         Material: flibe
#         Year: 1989
#         Isotope: T
#         Pre-exponential factor: 7.57×10⁻⁷ m²/s
#         Activation energy: 3.81×10⁻¹ eV/particle
#
#
#         Author: Lam
#         Material: flibe
#         Year: 2021
#         Isotope: T
#         Pre-exponential factor: 2.82×10⁻⁷ m²/s
#         Activation energy: 3.79×10⁻¹ eV/particle
#
#
#         Author: Lam
#         Material: flibe
#         Year: 2021
#         Isotope: T
#         Pre-exponential factor: 9.93×10⁻⁷ m²/s
#         Activation energy: 4.22×10⁻¹ eV/particle
#
#
#         Author: Nakamura
#         Material: flibe
#         Year: 2015
#         Isotope: H
#         Pre-exponential factor: 1.51×10⁻⁸ m²/s
#         Activation energy: 2.37×10⁻¹ eV/particle
# ----------  Running for dT=0 K  ----------
# Running for factor=1.0e-03
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
# Running for factor=1.0e-02
#   Newton iteration 0: r (abs) = 4.569e+04 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 4.986e-13 (tol = 1.000e-09) r (rel) = 1.091e-17 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.986e-13 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# Running for factor=1.0e-01
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
# Running for factor=1.0e+00
#   Newton iteration 0: r (abs) = 4.986e-13 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.986e-13 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 3.08e+05 H/s/m
# Average concentration: 1.19e+13 H/m3
# k: 1.75e-06 m/s
# ----------  Running for dT=0.05 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 3.06e+05 H/s/m
# Average concentration: 1.12e+13 H/m3
# k: 1.84e-06 m/s
# ----------  Running for dT=0.1 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 3.04e+05 H/s/m
# Average concentration: 1.11e+13 H/m3
# k: 1.86e-06 m/s
# ----------  Running for dT=0.175 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 3.02e+05 H/s/m
# Average concentration: 1.09e+13 H/m3
# k: 1.87e-06 m/s
# ----------  Running for dT=0.25 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 3.01e+05 H/s/m
# Average concentration: 1.09e+13 H/m3
# k: 1.88e-06 m/s
# ----------  Running for dT=1 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.95e+05 H/s/m
# Average concentration: 1.06e+13 H/m3
# k: 1.87e-06 m/s
# ----------  Running for dT=2.5 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.91e+05 H/s/m
# Average concentration: 1.06e+13 H/m3
# k: 1.86e-06 m/s
# ----------  Running for dT=5 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.91e+05 H/s/m
# Average concentration: 1.06e+13 H/m3
# k: 1.86e-06 m/s
# ----------  Running for dT=10 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.91e+05 H/s/m
# Average concentration: 1.03e+13 H/m3
# k: 1.92e-06 m/s
# ----------  Running for dT=0 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# ...
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1364: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   sublist = build_initializer_lists(val, sizes[1:], level+1, formatter, padlen=padlen, precision=precision)
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1458: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   initializer_lists = build_initializer_lists(self.values, self.sizes, 0,
# /Users/colinweaver/anaconda3/envs/festim-env/lib/python3.11/site-packages/ffc/uflacs/language/cnodes.py:1359: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   return [build_1d_initializer_list(values, formatter, padlen=padlen, precision=precision)]
# Solved problem in 2.40 s
# Total surface: 1.48e-02 m2
# Total flux: 3.08e+05 H/s/m
# Average concentration: 6.91e+13 H/m3
# k: 3.02e-07 m/s
# ----------  Running for dT=0.05 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.97e+05 H/s/m
# Average concentration: 6.33e+13 H/m3
# k: 3.18e-07 m/s
# ----------  Running for dT=0.1 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.89e+05 H/s/m
# Average concentration: 6.22e+13 H/m3
# k: 3.15e-07 m/s
# ----------  Running for dT=0.175 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.83e+05 H/s/m
# Average concentration: 6.14e+13 H/m3
# k: 3.12e-07 m/s
# ----------  Running for dT=0.25 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.79e+05 H/s/m
# Average concentration: 6.10e+13 H/m3
# k: 3.10e-07 m/s
# ----------  Running for dT=1 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.67e+05 H/s/m
# Average concentration: 5.97e+13 H/m3
# k: 3.04e-07 m/s
# ----------  Running for dT=2.5 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.59e+05 H/s/m
# Average concentration: 5.94e+13 H/m3
# k: 2.96e-07 m/s
# ----------  Running for dT=5 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.59e+05 H/s/m
# Average concentration: 5.90e+13 H/m3
# k: 2.98e-07 m/s
# ----------  Running for dT=10 K  ----------
# Running for factor=1.0e-03
# Running for factor=1.0e-02
# Running for factor=1.0e-01
# Running for factor=1.0e+00
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Solving steady state problem...
# Solved problem in 0.10 s
# Total surface: 1.48e-02 m2
# Total flux: 2.45e+05 H/s/m
# Average concentration: 5.62e+13 H/m3
# k: 2.95e-07 m/s

# %%
plt.figure()
for i in range(len(k_array_array)):
    plt.plot(dt_array, k_array_array[i], '-x', label=str(diffusivities[i].author + " (" + str(diffusivities[i].year) + ")"), linewidth=3)
plt.xlabel("Temperature difference [K]")
plt.ylabel("Transport Coefficient [m/s]")
plt.legend(loc = "lower right")
plt.show()
