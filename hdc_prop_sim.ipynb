# %%
from fenics import *
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Functions defining flibe properties:

# %%
def density_flibe(T):
    return 2413 - 0.488 * T  # kg/m3


def viscosity_flibe(T):
    e = 2.718281828459045
    return 1.16e-04 * e ** (3755 / (T + DOLFIN_EPS))  # Pa.s


def beta_flibe(T):
    return 1.8319e-04 + 5.55e-08 * T  # K-1


def plot_properties():
    T = np.linspace(400, 1200, 1000)

    mu = viscosity_flibe(T)
    rho = density_flibe(T)
    beta = beta_flibe(T)

    plt.figure()
    mu *= 1e03
    plt.plot(T, mu, label="viscosity")
    plt.ylim(0, 30)
    plt.legend()

    plt.figure()
    plt.plot(T, rho, label="density")
    plt.ylim(1800, 2150)
    plt.legend()

    plt.figure()
    beta *= 1e04
    plt.plot(T, beta, label="Thermal expansion")
    plt.ylim(1.6, 2.8)
    plt.legend()

    plt.show()

# %% [markdown]
# Simulation function:

# %%
def velocity_field(T_cold, T_hot, results_folder="Results/"):
    T_bulk = ((T_hot - T_cold) / 2) + T_cold

    N = 50
    my_mesh = RectangleMesh(Point(0, 0), Point(0.1, 0.1), N, N)
    V_ele = VectorElement("CG", my_mesh.ufl_cell(), 2)
    Q_ele = FiniteElement("CG", my_mesh.ufl_cell(), 1)
    T_ele = FiniteElement("CG", my_mesh.ufl_cell(), 1)
    W = FunctionSpace(my_mesh, MixedElement([V_ele, Q_ele, T_ele]))

    upT = Function(W)
    upT_old = Function(W)
    u, p, T = split(upT)
    v, q, S = TestFunctions(W)

    for factor in [1e-03, 1e-02, 1e-01, 1]:
        print("Running for factor={:.1e}".format(factor))

        g = Constant((0, -9.81))  # gravity acceleration in m/s2
        mu = viscosity_flibe(T_bulk)  # dynamic viscosity in kg/m/s
        rho = density_flibe(T_bulk)  # density in kg/m3
        rho_0 = density_flibe(T_bulk)  # density at T_cold
        cp = 2386  # heat capacity in J/(kg.K)
        thermal_cond = 1.1  # thermal conductivity in W/(m.K)
        beta = beta_flibe(T_bulk) * factor

        # CFD momentum
        F = (
            rho_0 * inner(dot(grad(u), u), v) * dx
            - inner(p, div(v)) * dx
            + mu * inner(grad(u), grad(v)) * dx
            + inner(rho_0 * beta * (T - T_bulk) * g, v) * dx
        )

        # CFD continuity
        F -= inner(q, div(u)) * dx

        # Heat transfer
        F += rho * cp * inner(dot(grad(T), u), S) * dx
        F += inner(thermal_cond * grad(T), grad(S)) * dx

        bcs = [
            DirichletBC(W.sub(0), Constant((0, 0)), "on_boundary"),
            DirichletBC(W.sub(2), T_hot, "on_boundary && x[0] == 0"),
            DirichletBC(W.sub(2), T_cold, "on_boundary && x[0] == 0.1"),
        ]

        solve(
            F == 0,
            upT,
            bcs=bcs,
            solver_parameters={
                "newton_solver": {
                    "linear_solver": "mumps",
                    "absolute_tolerance": 1e-09,
                    "relative_tolerance": 1e-09,
                    "maximum_iterations": 25,
                }
            },
        )

        upT_old.assign(upT)

    u, p, T = upT.split()

    XDMFFile(results_folder + "velocity_field.xdmf").write(u)
    XDMFFile(results_folder + "temperature_field.xdmf").write(T)

# %%
if __name__ == "__main__":
    # plot_properties()

    T_cold_temps = [3]
    T_hot = 700 + 273.15
    for dt in T_cold_temps:
        T_cold = T_hot - dt
        foldername = f"Results_prop_sim/dt={dt}/"
        velocity_field(T_cold=T_cold, T_hot=T_hot, results_folder=foldername)
# Out:
# Running for factor=1.0e-03
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Running for factor=1.0e-02
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.091e+04 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 1.240e+00 (tol = 1.000e-09) r (rel) = 4.013e-05 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 3.564e-01 (tol = 1.000e-09) r (rel) = 1.153e-05 (tol = 1.000e-09)
#   Newton iteration 3: r (abs) = 9.151e-02 (tol = 1.000e-09) r (rel) = 2.961e-06 (tol = 1.000e-09)
#   Newton iteration 4: r (abs) = 4.112e-03 (tol = 1.000e-09) r (rel) = 1.330e-07 (tol = 1.000e-09)
#   Newton iteration 5: r (abs) = 9.133e-06 (tol = 1.000e-09) r (rel) = 2.955e-10 (tol = 1.000e-09)
#   Newton solver finished in 5 iterations and 5 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.834e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 1.661e+00 (tol = 1.000e-09) r (rel) = 1.689e+05 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 3.587e-01 (tol = 1.000e-09) r (rel) = 3.647e+04 (tol = 1.000e-09)
#   Newton iteration 3: r (abs) = 5.398e-02 (tol = 1.000e-09) r (rel) = 5.490e+03 (tol = 1.000e-09)
#   Newton iteration 4: r (abs) = 9.479e-04 (tol = 1.000e-09) r (rel) = 9.639e+01 (tol = 1.000e-09)
#   Newton iteration 5: r (abs) = 2.288e-07 (tol = 1.000e-09) r (rel) = 2.327e-02 (tol = 1.000e-09)
#   Newton iteration 6: r (abs) = 8.253e-12 (tol = 1.000e-09) r (rel) = 8.393e-07 (tol = 1.000e-09)
#   Newton solver finished in 6 iterations and 6 linear solver iterations.
# Running for factor=1.0e-01
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
# Running for factor=1.0e+00
#   Newton iteration 0: r (abs) = 3.296e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 3.795e+00 (tol = 1.000e-09) r (rel) = 1.151e+05 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 1.172e+00 (tol = 1.000e-09) r (rel) = 3.556e+04 (tol = 1.000e-09)
#   Newton iteration 3: r (abs) = 2.522e-01 (tol = 1.000e-09) r (rel) = 7.654e+03 (tol = 1.000e-09)
#   Newton iteration 4: r (abs) = 9.208e-03 (tol = 1.000e-09) r (rel) = 2.794e+02 (tol = 1.000e-09)
#   Newton iteration 5: r (abs) = 1.311e-05 (tol = 1.000e-09) r (rel) = 3.978e-01 (tol = 1.000e-09)
#   Newton iteration 6: r (abs) = 4.445e-11 (tol = 1.000e-09) r (rel) = 1.349e-06 (tol = 1.000e-09)
#   Newton solver finished in 6 iterations and 6 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.084e-04 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 7.828e+00 (tol = 1.000e-09) r (rel) = 2.538e+04 (tol = 1.000e-09)
#   Newton iteration 2: r (abs) = 3.606e+00 (tol = 1.000e-09) r (rel) = 1.169e+04 (tol = 1.000e-09)
#   Newton iteration 3: r (abs) = 8.792e-01 (tol = 1.000e-09) r (rel) = 2.851e+03 (tol = 1.000e-09)
#   Newton iteration 4: r (abs) = 6.802e-02 (tol = 1.000e-09) r (rel) = 2.206e+02 (tol = 1.000e-09)
#   Newton iteration 5: r (abs) = 3.159e-04 (tol = 1.000e-09) r (rel) = 1.024e+00 (tol = 1.000e-09)
#   Newton iteration 6: r (abs) = 4.562e-09 (tol = 1.000e-09) r (rel) = 1.479e-05 (tol = 1.000e-09)
#   Newton iteration 7: r (abs) = 8.734e-12 (tol = 1.000e-09) r (rel) = 2.832e-08 (tol = 1.000e-09)
#   Newton solver finished in 7 iterations and 7 linear solver iterations.
